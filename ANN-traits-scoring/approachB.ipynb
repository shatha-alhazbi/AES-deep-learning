# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.model_selection import KFold
import pandas as pd
from sklearn.metrics import cohen_kappa_score
import time
from datetime import datetime
from tqdm.auto import tqdm
import math


#gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\nUsing device: {device}")


def quadratic_weighted_kappa(y_true, y_pred):
    """Calculate Quadratic Weighted Kappa score."""
    return cohen_kappa_score(y_true, np.round(y_pred), weights='quadratic')


# Score ranges dictionary with all traits
SCORE_RANGES = {
        1: {'sentence_fluency': (1, 6), 'word_choice': (1, 6), 'conventions': (1, 6),'organization': (1, 6),
            'content': (1, 6), 'holistic': (2, 12)},
        2: {'sentence_fluency': (1, 6), 'word_choice': (1, 6), 'conventions': (1, 6),'organization': (1, 6),
            'content': (1, 6), 'holistic': (1, 6)},
        3: {'narrativity': (0, 3), 'language': (0, 3), 'prompt_adherence': (0, 3), 'content': (0, 3),
            'holistic': (0, 3)},
        4: {'narrativity': (0, 3), 'language': (0, 3), 'prompt_adherence': (0, 3), 'content': (0, 3),
            'holistic': (0, 3)},
        5: {'narrativity': (0, 4), 'language': (0, 4), 'prompt_adherence': (0, 4), 'content': (0, 4),
            'holistic': (0, 4)},
        6: {'narrativity': (0, 4), 'language': (0, 4), 'prompt_adherence': (0, 4), 'content': (0, 4),
            'holistic': (0, 4)},
        7: {'conventions': (0, 6), 'organization': (0, 6), 'content': (0, 6),'holistic': (0, 30)},
        8: {'sentence_fluency': (2, 12), 'word_choice': (2, 12), 'conventions': (2, 12),'organization': (2, 12),
            'content': (2, 12), 'holistic': (0, 60)}}

#traits in order, is going to be output order
traits = ['holistic', 'content', 'organization', 'word_choice', 'sentence_fluency',
               'conventions', 'prompt_adherence', 'language', 'narrativity']

def read_data(path):
    """Reads the CSV file and returns a dictionary with parallel lists."""
    data = pd.read_csv(path)
    return {
        'essay_ids': data['essay_id'].values,
        'prompt_ids': data['prompt_id'].values,
        'essay_text': data['essay_text'].values,
        'features': data.iloc[:, 12:].values,
        'holistic': data['holistic'].values,
        'content': data['content'].values,
        'organization': data['organization'].values,
        'word_choice': data['word_choice'].values,
        'sentence_fluency': data['sentence_fluency'].values,
        'conventions': data['conventions'].values,
        'prompt_adherence': data['prompt_adherence'].values,
        'language': data['language'].values,
        'narrativity': data['narrativity'].values
    }
#function to normalize the score based on its range
def normalize_score(score, score_range):
    return (score - score_range[0]) / (score_range[1] - score_range[0])

#return it back
def denormalize_score(norm_score, score_range):
    return norm_score * (score_range[1] - score_range[0]) + score_range[0]

#get binary mask to show which trait/score is valid for a prompt
#example, prompt 1 essay mask is [1,1,1,1,1,1,0,0,0]
def get_trait_mask(prompt_id):
    mask = torch.zeros(len(traits))
    for i, trait in enumerate(traits):
        if trait in SCORE_RANGES[prompt_id]:
            mask[i] = 1.0
    return mask

class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_unit, num_layers):
        super(NeuralNetwork, self).__init__()

        layers = []
        #input layer and activation define
        layers.append(nn.Linear(input_size, hidden_unit))
        layers.append(nn.ReLU())

        #hidden layres in list for tuning later
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_unit, hidden_unit))
            layers.append(nn.ReLU())

        #output layer one node for each trait including holistic
        layers.append(nn.Linear(hidden_unit, len(traits)))

        self.model = nn.Sequential(*layers)

        #he initialization for params
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x):
         return self.model(x)

class MultivariateLossFn(nn.Module):
    """Loss function based on probability of prediction being correct MAKE SURE TO MAKE IT USE ONLY VALID PROMPTS!!"""
    def __init__(self, sigma=1.0):
        super(MultivariateLossFn, self).__init__()
        self.sigma = sigma
        self.const = 1.0 / (math.sqrt(2 * math.pi) * sigma)

    def forward(self, outputs, targets, masks):
        squared_diff = (targets - outputs) ** 2
        exp_term = torch.exp(-squared_diff / (2 * self.sigma ** 2))
        prob_term = self.const * exp_term
        masked_probs = prob_term * masks #masked only those with values of 1 (valid prompts)
        valid_probs = masked_probs + (1 - masks) + 1e-7 #add epsilon to avoid log(0)
        log_prob = torch.log(valid_probs)
        loss = -torch.sum(log_prob * masks, dim=1) / torch.sum(masks, dim=1)
        return loss.mean()

def normalize_all_scores(data_dict, prompt_id):
    """
    normalizing + masking
    -normalizes those present scores to [0,1]
    -creates mask (1 for valid traits, 0 for invalid)
    """
    normalized_scores = torch.zeros(len(traits))
    mask = torch.zeros(len(traits))

    for i, trait in enumerate(traits):
        if trait in SCORE_RANGES[prompt_id]:
            score = data_dict[trait]
            score_range = SCORE_RANGES[prompt_id][trait]
            #do normalizing of the present scores
            normalized_scores[i] = normalize_score(score, score_range)
            #mask it as 1 to show its present, others will remain 0
            mask[i] = 1.0 

    return normalized_scores, mask

def denormalize_all_scores(normalized_scores, prompt_id):
    """
    denormalization
    -converts all normalized scores back to original ranges
    -only do that for traits valid for the prompt
    """
    denormalized_scores = torch.zeros_like(normalized_scores)

    for i, trait in enumerate(traits):
        if trait in SCORE_RANGES[prompt_id]:
            score_range = SCORE_RANGES[prompt_id][trait]
            #denormalize
            denormalized_scores[i] = denormalize_score(normalized_scores[i], score_range)

    return denormalized_scores

#train and evaluate model for given a target prompt id. 
#one prompt will run this after another, each with their id
def train_and_evaluate_prompt(test_prompt_id, data):
    print(f"\n{'-'*60}")
    print(f"model starts training process for target prompt {test_prompt_id}")
    print(f"{'-'*60}\n")

    #define train prompts to be all except test prompt
    train_prompt_range = [i for i in range(1, 9) if i != test_prompt_id]

    #prep data
    filter = data['prompt_ids'] != test_prompt_id
    prompt_ids = data['prompt_ids'][filter]
    features = torch.FloatTensor(data['features'][filter]).to(device)

    #NORMALIZATION + MASKING
    scores_list = []
    masks_list = []
    #for each essay,
    for idx, prompt_id in enumerate(prompt_ids):
        #temporary dict with scores for this essay
        essay_data = {trait: data[trait][filter][idx] for trait in traits}
        #normalize scores and create mask for this essay
        normalized_scores, mask = normalize_all_scores(essay_data, prompt_id)
        scores_list.append(normalized_scores) #add it to scores
        masks_list.append(mask) #add the mask

    normalized_scores = torch.stack(scores_list)
    score_masks = torch.stack(masks_list).to(device)
    normalized_scores = normalized_scores.to(device)

    print(f"Feature shape: {features.shape}")
    print(f"Scores shape: {normalized_scores.shape}")

    #grid search params
    k_fold = KFold(n_splits=7, shuffle=False) #k fold not shuffled, bc we need one prompt per fold cv
    hidden_units = [8, 16, 32]
    num_layers_options = [1, 2, 4, 8]
    learning_rates = [0.001, 0.01, 0.1]
    batch_size = 4

    #try all possible combinations of those params
    total_combinations = len(hidden_units) * len(num_layers_options) * len(learning_rates)
    print(f"Model does grid search with {total_combinations} combinations")
    print(f"- hidden units per layer (D): {hidden_units}")
    print(f"- num of layers (k): {num_layers_options}")
    print(f"- learning rates: {learning_rates}")
    print(f"- batch size (fixed): {batch_size}\n")

    best_avg_qwk = -1
    best_params = None
    combination_count = 0
    start_time = time.time()
    # ------------------------------------------------------- GRID SEARCH -------------------------------------------------------
    #make sure to track best performing parameters
    for hidden_unit in hidden_units:
        for num_layers in num_layers_options:
            for lr in learning_rates:
                combination_count += 1
                print(f"\n--------------- testing combo {combination_count}/{total_combinations}--------------")
                print(f"hyperparams: units per layer D={hidden_unit}, num of layers k={num_layers}, lr={lr}\n")

                fold_qwks_by_trait = {trait: [] for trait in traits}
                fold_start_time = time.time()

                #7-fold cross-validation (heldout still heldout!)
                for fold, (train_prompt_idx, val_prompt_idx) in enumerate(k_fold.split(train_prompt_range)):
                    train_prompts = [train_prompt_range[i] for i in train_prompt_idx]
                    val_prompt = train_prompt_range[val_prompt_idx[0]]

                    train_filter = np.isin(prompt_ids, train_prompts)
                    val_filter = (prompt_ids == val_prompt)

                    X_train, X_val = features[train_filter], features[val_filter]
                    y_train, y_val = normalized_scores[train_filter], normalized_scores[val_filter]
                    mask_train, mask_val = score_masks[train_filter], score_masks[val_filter]

                    model = NeuralNetwork(86, hidden_unit, num_layers).to(device)
                    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=0.1)
                    criterion = MultivariateLossFn()

                    best_val_loss = float('inf')
                    epochs_no_improve = 0
                    best_epoch_qwks = {}

                    # Training loop
                    for epoch in range(15):
                        model.train()
                        epoch_loss = 0
                        num_batches = 0

                        indices = torch.randperm(len(X_train))
                        X_train = X_train[indices]
                        y_train = y_train[indices]
                        mask_train = mask_train[indices]

                        for i in range(0, len(X_train), batch_size):
                            batch_X = X_train[i:i + batch_size]
                            batch_y = y_train[i:i + batch_size]
                            batch_mask = mask_train[i:i + batch_size]

                            optimizer.zero_grad()
                            outputs = model(batch_X)
                            loss = criterion(outputs, batch_y, batch_mask)
                            loss.backward()
                            optimizer.step()

                            epoch_loss += loss.item()
                            num_batches += 1

                        avg_epoch_loss = epoch_loss / num_batches

                        #validation 
                        model.eval()
                        with torch.no_grad():
                            val_pred = model(X_val)
                            epoch_trait_qwks = {}

                            #calc QWK for each trait
                            #DENORMALIZING HERE
                            for i, trait in enumerate(traits):
                                if trait in SCORE_RANGES[val_prompt]:
                                     #DENORMALIZATION
                                    val_pred_trait = denormalize_score(
                                        val_pred[:, i].cpu().numpy(),
                                        SCORE_RANGES[val_prompt][trait]
                                    )
                                    val_true_trait = denormalize_score(
                                        y_val[:, i].cpu().numpy(),
                                        SCORE_RANGES[val_prompt][trait]
                                    )
                                    qwk = quadratic_weighted_kappa(
                                        val_true_trait.round(),
                                        val_pred_trait
                                    )
                                    epoch_trait_qwks[trait] = qwk

                            # Update best QWKs if this is the best epoch
                            if avg_epoch_loss < best_val_loss:
                                best_val_loss = avg_epoch_loss
                                best_epoch_qwks = epoch_trait_qwks.copy()
                                epochs_no_improve = 0
                            else:
                                epochs_no_improve += 1

                        if epochs_no_improve >= 3:
                            break

                    #store best QWKs for this fold
                    for trait, qwk in best_epoch_qwks.items():
                        fold_qwks_by_trait[trait].append(qwk)

                    #print avg QWK for this validation prompt
                    prompt_avg_qwk = np.mean(list(best_epoch_qwks.values()))
                    print(f"validation prompt no. {val_prompt}: Avg QWK of all scores: {prompt_avg_qwk:.4f}")

                #print average QWK across all folds
                avg_trait_qwks = {}
                for trait in traits:
                    if fold_qwks_by_trait[trait]:
                        avg_trait_qwks[trait] = np.mean(fold_qwks_by_trait[trait])

                avg_qwk = np.mean(list(avg_trait_qwks.values()))
                print(f"\avg QWK across all prompts: {avg_qwk:.4f}")

                #tracking best params
                if avg_qwk > best_avg_qwk:
                    best_avg_qwk = avg_qwk
                    best_params = {
                        'hidden_unit': hidden_unit,
                        'num_layers': num_layers,
                        'learning_rate': lr
                    }
                    print("BEST COMBO FOUND =)!")
    # -------------------------------------------------------------------------------------------------------------------------------

    # ------------------------------------------------------- BATCH SIZE OPTIM -------------------------------------------------------
    #make sure to track best performing batch size

    #data for batch size optimization, dividing dataset into 85% trian 15% test. 
    #the validation prompt being use for batch size optimization is always 8 unless taregt prompt 8 then its 7
    validation_prompt_id = 8 if test_prompt_id != 8 else 7
    ranges = [p for p in train_prompt_range if p != validation_prompt_id] #ranges of prompts are all except the test and validation

    print(f"\n{'-'*50}")
    print("starting the batch size optim with best params from grid search")
    print(f"{'-'*50}\n")
    train_filter = (data['prompt_ids'] != test_prompt_id) & (data['prompt_ids'] != validation_prompt_id) #use data that isnt the test prompt or the validation prompt
    val_filter = data['prompt_ids'] == validation_prompt_id #the validation prompt (prompt 8 for all models rn, and for prompt 8 its 7)

    X_train = torch.FloatTensor(data['features'][train_filter]).to(device)
    prompt_ids_train = data['prompt_ids'][train_filter]

    X_val = torch.FloatTensor(data['features'][val_filter]).to(device)
    prompt_ids_val = data['prompt_ids'][val_filter]

    #normalized scores and masks for training data
    train_scores_list = []
    train_masks_list = []
    for idx, prompt_id in enumerate(prompt_ids_train):
        essay_data = {trait: data[trait][train_filter][idx] for trait in traits} #dict
        normalized_scores, mask = normalize_all_scores(essay_data, prompt_id)
        train_scores_list.append(normalized_scores)
        train_masks_list.append(mask)

    y_train = torch.stack(train_scores_list).to(device)
    mask_train = torch.stack(train_masks_list).to(device)

    #normalized scores and masks for validation data
    #NORMALIZATION + MASKING
    val_scores_list = []
    val_masks_list = []
    for idx, prompt_id in enumerate(prompt_ids_val):
        essay_data = {trait: data[trait][val_filter][idx] for trait in traits}
        normalized_scores, mask = normalize_all_scores(essay_data, prompt_id)
        val_scores_list.append(normalized_scores)
        val_masks_list.append(mask)

    y_val = torch.stack(val_scores_list).to(device)
    mask_val = torch.stack(val_masks_list).to(device)

    print("Dataset after separation:")
    print(f"Training: {len(X_train)} essays (prompts {ranges})")
    print(f"Validation: {len(X_val)} essays (prompt {validation_prompt_id})")
    print(f"Held out: Prompt {test_prompt_id} (for final testing)\n")

    batch_sizes = [4, 8, 16, 32]
    print(f"testing batch sizes: {batch_sizes}")

    best_batch_qwk = -1
    best_batch_size = None
    batch_start_time = time.time()

    criterion = MultivariateLossFn()

    for batch_size in batch_sizes:
        print(f"\n------------ batch size: {batch_size} --------------")

        model = NeuralNetwork(
            input_size=86,
            hidden_unit=best_params['hidden_unit'],
            num_layers=best_params['num_layers']
        ).to(device)

        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=best_params['learning_rate'],
            betas=(0.9, 0.999),
            weight_decay=0.1
        )

        best_val_loss = float('inf')
        epochs_without_improvement = 0

        for epoch in range(15):
            model.train()
            epoch_loss = 0
            num_batches = 0

            # Shuffle training data
            indices = torch.randperm(len(X_train))
            X_train = X_train[indices]
            y_train = y_train[indices]
            mask_train = mask_train[indices]

            for i in range(0, len(X_train), batch_size):
                batch_X = X_train[i:i + batch_size]
                batch_y = y_train[i:i + batch_size]
                batch_mask = mask_train[i:i + batch_size]

                optimizer.zero_grad()
                outputs = model(batch_X)
                loss = criterion(outputs, batch_y, batch_mask)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()
                num_batches += 1

            avg_epoch_loss = epoch_loss / num_batches

            # Validation step
            model.eval()
            with torch.no_grad():
                val_outputs = model(X_val)
                val_loss = criterion(val_outputs, y_val, mask_val)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1

            if epochs_without_improvement >= 3:
                print(f"early stopping at epoch {epoch + 1}")
                break

            if (epoch + 1) % 5 == 0:
                print(f"Epoch {epoch + 1}/15 - Train Loss: {avg_epoch_loss:.6f}, Val Loss: {val_loss:.6f}")

        #evaluate QWK on validation set for all traits
        model.eval()
        with torch.no_grad():
            val_pred = model(X_val)
            val_qwks = {}
            for i, trait in enumerate(traits):
                if trait in SCORE_RANGES[validation_prompt_id]:
                    val_pred_trait = denormalize_score(
                        val_pred[:, i].cpu().numpy(),
                        SCORE_RANGES[validation_prompt_id][trait]
                    )
                    val_true_trait = denormalize_score(
                        y_val[:, i].cpu().numpy(),
                        SCORE_RANGES[validation_prompt_id][trait]
                    )
                    val_qwks[trait] = quadratic_weighted_kappa(
                        val_true_trait.round(),
                        val_pred_trait
                    )

            avg_qwk = np.mean(list(val_qwks.values()))
            print(f"avg validation QWK across all traits: {avg_qwk:.4f}")
            print("trait QWKs:")
            for trait, qwk in val_qwks.items():
                print(f"{trait}: {qwk:.4f}")

            #tracking best batch size
            if avg_qwk > best_batch_qwk:
                best_batch_qwk = avg_qwk
                best_batch_size = batch_size
                print("New best batch size found!!!!! :)")

    batch_time = time.time() - batch_start_time
    print(f"\n{'-'*50}")
    print("done with batch size optimization :D")
    print(f"total time taken: {batch_time:.2f} seconds ({batch_time/60:.2f} minutes)")
    print(f"best batch size: {best_batch_size}")
    print(f"best validation average QWK: {best_batch_qwk:.4f}")
    print(f"{'-'*50}\n")
    # -------------------------------------------------------------------------------------------------------------------------------

    # ------------------------------------------------------- FINAL MODEL TRAINING -------------------------------------------------------
    final_params = best_params.copy()
    final_params['batch_size'] = best_batch_size

    #final training data (all data except test prompt)
    final_train_filter = data['prompt_ids'] != test_prompt_id
    X_final_train = torch.FloatTensor(data['features'][final_train_filter]).to(device)
    prompt_ids_final = data['prompt_ids'][final_train_filter]

    #normalized scores and masks for all training data
    final_scores_list = []
    final_masks_list = []
    for idx, prompt_id in enumerate(prompt_ids_final):
        essay_data = {trait: data[trait][final_train_filter][idx] for trait in traits}
        normalized_scores, mask = normalize_all_scores(essay_data, prompt_id)
        final_scores_list.append(normalized_scores)
        final_masks_list.append(mask)

    y_final_train = torch.stack(final_scores_list).to(device)
    mask_final_train = torch.stack(final_masks_list).to(device)

    final_model = NeuralNetwork(
        input_size=86,
        hidden_unit=final_params['hidden_unit'],
        num_layers=final_params['num_layers']
    ).to(device)

    optimizer = torch.optim.AdamW(
        final_model.parameters(),
        lr=final_params['learning_rate'],
        betas=(0.9, 0.999),
        weight_decay=0.1
    )
    criterion = MultivariateLossFn()

    print("starting training the final model")
    for epoch in range(15):
        final_model.train()
        epoch_loss = 0
        num_batches = 0

        #shuffling training data
        indices = torch.randperm(len(X_final_train))
        X_final_train = X_final_train[indices]
        y_final_train = y_final_train[indices]
        mask_final_train = mask_final_train[indices]

        for i in range(0, len(X_final_train), final_params['batch_size']):
            batch_X = X_final_train[i:i + final_params['batch_size']]
            batch_y = y_final_train[i:i + final_params['batch_size']]
            batch_mask = mask_final_train[i:i + final_params['batch_size']]

            optimizer.zero_grad()
            outputs = final_model(batch_X)
            loss = criterion(outputs, batch_y, batch_mask)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            num_batches += 1

        if (epoch + 1) % 5 == 0:
            avg_epoch_loss = epoch_loss / num_batches
            print(f"Epoch {epoch + 1}/15 - Training Loss: {avg_epoch_loss:.6f}")
    # -------------------------------------------------------------------------------------------------------------------------------

    #testing on the target held out prompt
    test_filter = data['prompt_ids'] == test_prompt_id
    X_test = torch.FloatTensor(data['features'][test_filter]).to(device)

    #test scores and masks
    #NORMALIZATION + MASKING
    test_scores_list = []
    test_masks_list = []
    for idx in range(sum(test_filter)):
        essay_data = {trait: data[trait][test_filter][idx] for trait in traits}
        normalized_scores, mask = normalize_all_scores(essay_data, test_prompt_id)
        test_scores_list.append(normalized_scores)
        test_masks_list.append(mask)

    y_test = torch.stack(test_scores_list)
    mask_test = torch.stack(test_masks_list)

    #evaluate on test set
    final_model.eval()
    with torch.no_grad():
        test_pred = final_model(X_test)

        #calculate QWK for each trait
        #DENORMALIZATION
        trait_qwks = {}
        for i, trait in enumerate(traits):
            if trait in SCORE_RANGES[test_prompt_id]:  #evaluate the available traits only
                pred_scores = denormalize_score(
                    test_pred[:, i].cpu().numpy(),
                    SCORE_RANGES[test_prompt_id][trait]
                )
                true_scores = denormalize_score(
                    y_test[:, i].numpy(),
                    SCORE_RANGES[test_prompt_id][trait]
                )
                trait_qwks[trait] = quadratic_weighted_kappa(
                    true_scores.round(),
                    pred_scores
                )

    print(f"\n{'-'*50}")
    print(f"Test set results on target prompt {test_prompt_id}:")
    for trait, qwk in trait_qwks.items():
        print(f"{trait.capitalize()} QWK: {qwk:.4f}")
    print(f"final best params: {final_params}")
    print(f"{'-'*50}\n")

    # Save the model
    final_model = final_model.cpu()
    scripted_model = torch.jit.script(final_model)
    model_path = f"model-B-{test_prompt_id}.pt"
    scripted_model.save(model_path)
    print(f"model was saved as {model_path}")

    return final_params, trait_qwks

#Train and save deployment model using all data
def train_deployment_model(data, best_overall_params):
    print(f"\n{'-'*50}")
    print(f"Training deployment model using best parameters:")
    print(f"Parameters: {best_overall_params}")
    print(f"{'-'*50}")

    features = torch.FloatTensor(data['features']).to(device)
    prompt_ids = data['prompt_ids']

    #normalized scores and masks for all data
    scores_list = []
    masks_list = []
    for idx, prompt_id in enumerate(prompt_ids):
        essay_data = {trait: data[trait][idx] for trait in traits}
        normalized_scores, mask = normalize_all_scores(essay_data, prompt_id)
        scores_list.append(normalized_scores)
        masks_list.append(mask)

    all_scores = torch.stack(scores_list).to(device)
    all_masks = torch.stack(masks_list).to(device)

    #model for deployment
    deploy_model = NeuralNetwork(
        input_size=86,
        hidden_unit=best_overall_params['hidden_unit'],
        num_layers=best_overall_params['num_layers']
    ).to(device)

    optimizer = torch.optim.AdamW(
        deploy_model.parameters(),
        lr=best_overall_params['learning_rate'],
        betas=(0.9, 0.999),
        weight_decay=0.1
    )
    criterion = MultivariateLossFn()
    batch_size = best_overall_params['batch_size']

    #train on all dataset
    print("starting training of the deployment model")
    for epoch in range(15):
        deploy_model.train()
        epoch_loss = 0
        num_batches = 0

        # Shuffle indices for each epoch
        indices = torch.randperm(len(features))
        features = features[indices]
        all_scores = all_scores[indices]
        all_masks = all_masks[indices]

        for i in range(0, len(features), batch_size):
            batch_X = features[i:i + batch_size]
            batch_y = all_scores[i:i + batch_size]
            batch_mask = all_masks[i:i + batch_size]

            optimizer.zero_grad()
            outputs = deploy_model(batch_X)
            loss = criterion(outputs, batch_y, batch_mask)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            num_batches += 1

        if (epoch + 1) % 5 == 0:
            avg_epoch_loss = epoch_loss / num_batches
            print(f"Epoch {epoch + 1}/15 - Training Loss: {avg_epoch_loss:.6f}")

    # Save deployment model
    print("\nSaving deployment model...")
    deploy_model = deploy_model.cpu()
    scripted_model = torch.jit.script(deploy_model)
    model_path = "model-B-deploy.pt"
    scripted_model.save(model_path)
    print(f"Deployment model saved as {model_path}")

def main():
    print(f"\n{'-'*50}")
    print(f"starting full cross-prompt evaluation at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'-'*50}\n")

    data = read_data('/kaggle/input/dataset/dataset.csv')

    results = {}
    best_overall_params = None
    best_overall_avg_qwk = -1

    #running train and evaluate for each prompt
    for target_prompt in range(1, 9):
        params, trait_qwks = train_and_evaluate_prompt(target_prompt, data)
        #TRACKING BEST PARAMS TO LATEAR USE IN DEPLOYMENT
        results[target_prompt] = {
            'parameters': params,
            'trait_qwks': trait_qwks
        }

        #keep best performing parameters based on average QWK across all traits
        avg_qwk = np.mean(list(trait_qwks.values()))
        if avg_qwk > best_overall_avg_qwk:
            best_overall_avg_qwk = avg_qwk
            best_overall_params = params.copy()

    #print final summary
    print("\nResults:")
    print("-" * 50)
    for prompt, result in results.items():
        print(f"\nPrompt {prompt}:")
        for trait, qwk in result['trait_qwks'].items():
            print(f"  {trait.capitalize()} QWK: {qwk:.4f}")
        print(f"  Parameters: {result['parameters']}")
    print("-" * 50)

    #print average QWK for each trait
    all_trait_qwks = {trait: [] for trait in traits}
    for result in results.values():
        for trait, qwk in result['trait_qwks'].items():
            all_trait_qwks[trait].append(qwk)

    print("\navg QWK per trait:")
    for trait in traits:
        if all_trait_qwks[trait]:  #only print if we have scores for this trait
            avg_qwk = np.mean(all_trait_qwks[trait])
            print(f"{trait.capitalize()}: {avg_qwk:.4f}")

    #train the deployment model
    train_deployment_model(data, best_overall_params)


    print("\nFinal saved models:")
    print("-" * 50)
    print("Individual prompt models:")
    for i in range(1, 9):
        print(f"  - model-B-{i}.pt")
    print("Deployment model:")
    print("  - model-B-deploy.pt")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
#
# --------------------------------------------------
# Starting full cross-prompt evaluation at 2024-12-06 12:41:50
# --------------------------------------------------
#
# Reading the dataset
#
#
# ------------------------------------------------------------
# model starts training process for target prompt 1
# ------------------------------------------------------------
#
# Feature shape: torch.Size([11193, 86])
# Scores shape: torch.Size([11193, 9])
# Model does grid search with 36 combinations
# - hidden units per layer (D): [8, 16, 32]
# - num of layers (k): [1, 2, 4, 8]
# - learning rates: [0.001, 0.01, 0.1]
# - batch size (fixed): 4
#
#
# --------------- testing combo 1/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4904
# validation prompt no. 3: Avg QWK of all scores: 0.5687
# validation prompt no. 4: Avg QWK of all scores: 0.5412
# validation prompt no. 5: Avg QWK of all scores: 0.5943
# validation prompt no. 6: Avg QWK of all scores: 0.5457
# validation prompt no. 7: Avg QWK of all scores: 0.3309
# validation prompt no. 8: Avg QWK of all scores: 0.4120
# vg QWK across all prompts: 0.4796
# BEST COMBO FOUND =)!
#
# --------------- testing combo 2/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4526
# validation prompt no. 3: Avg QWK of all scores: 0.4869
# validation prompt no. 4: Avg QWK of all scores: 0.4604
# validation prompt no. 5: Avg QWK of all scores: 0.6236
# validation prompt no. 6: Avg QWK of all scores: 0.5136
# validation prompt no. 7: Avg QWK of all scores: 0.3696
# validation prompt no. 8: Avg QWK of all scores: 0.3719
# vg QWK across all prompts: 0.4480
#
# --------------- testing combo 3/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 4/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4862
# validation prompt no. 3: Avg QWK of all scores: 0.5641
# validation prompt no. 4: Avg QWK of all scores: 0.5284
# validation prompt no. 5: Avg QWK of all scores: 0.6096
# validation prompt no. 6: Avg QWK of all scores: 0.5271
# validation prompt no. 7: Avg QWK of all scores: 0.3379
# validation prompt no. 8: Avg QWK of all scores: 0.4357
# vg QWK across all prompts: 0.4825
# BEST COMBO FOUND =)!
#
# --------------- testing combo 5/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4155
# validation prompt no. 3: Avg QWK of all scores: 0.4653
# validation prompt no. 4: Avg QWK of all scores: 0.4912
# validation prompt no. 5: Avg QWK of all scores: 0.5900
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3228
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.2834
#
# --------------- testing combo 6/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 7/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.5016
# validation prompt no. 3: Avg QWK of all scores: 0.5847
# validation prompt no. 4: Avg QWK of all scores: 0.5322
# validation prompt no. 5: Avg QWK of all scores: 0.6441
# validation prompt no. 6: Avg QWK of all scores: 0.5416
# validation prompt no. 7: Avg QWK of all scores: 0.3749
# validation prompt no. 8: Avg QWK of all scores: 0.3029
# vg QWK across all prompts: 0.4655
#
# --------------- testing combo 8/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.3920
# validation prompt no. 3: Avg QWK of all scores: 0.5551
# validation prompt no. 4: Avg QWK of all scores: 0.4607
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3392
# validation prompt no. 8: Avg QWK of all scores: 0.2794
# vg QWK across all prompts: 0.2835
#
# --------------- testing combo 9/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 10/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4720
# validation prompt no. 3: Avg QWK of all scores: 0.5521
# validation prompt no. 4: Avg QWK of all scores: 0.4912
# validation prompt no. 5: Avg QWK of all scores: 0.5912
# validation prompt no. 6: Avg QWK of all scores: 0.5306
# validation prompt no. 7: Avg QWK of all scores: 0.3732
# validation prompt no. 8: Avg QWK of all scores: 0.3614
# vg QWK across all prompts: 0.4539
#
# --------------- testing combo 11/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.3196
# validation prompt no. 3: Avg QWK of all scores: 0.5087
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.3493
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.1575
#
# --------------- testing combo 12/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 13/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4843
# validation prompt no. 3: Avg QWK of all scores: 0.5663
# validation prompt no. 4: Avg QWK of all scores: 0.5639
# validation prompt no. 5: Avg QWK of all scores: 0.6152
# validation prompt no. 6: Avg QWK of all scores: 0.5435
# validation prompt no. 7: Avg QWK of all scores: 0.3326
# validation prompt no. 8: Avg QWK of all scores: 0.4679
# vg QWK across all prompts: 0.4976
# BEST COMBO FOUND =)!
#
# --------------- testing combo 14/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4449
# validation prompt no. 3: Avg QWK of all scores: 0.5897
# validation prompt no. 4: Avg QWK of all scores: 0.4439
# validation prompt no. 5: Avg QWK of all scores: 0.6037
# validation prompt no. 6: Avg QWK of all scores: 0.5339
# validation prompt no. 7: Avg QWK of all scores: 0.4315
# validation prompt no. 8: Avg QWK of all scores: 0.3746
# vg QWK across all prompts: 0.4650
#
# --------------- testing combo 15/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 16/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.5198
# validation prompt no. 3: Avg QWK of all scores: 0.5813
# validation prompt no. 4: Avg QWK of all scores: 0.5672
# validation prompt no. 5: Avg QWK of all scores: 0.6277
# validation prompt no. 6: Avg QWK of all scores: 0.4883
# validation prompt no. 7: Avg QWK of all scores: 0.3559
# validation prompt no. 8: Avg QWK of all scores: 0.4443
# vg QWK across all prompts: 0.4965
#
# --------------- testing combo 17/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4109
# validation prompt no. 3: Avg QWK of all scores: 0.4363
# validation prompt no. 4: Avg QWK of all scores: 0.5355
# validation prompt no. 5: Avg QWK of all scores: 0.5920
# validation prompt no. 6: Avg QWK of all scores: 0.4554
# validation prompt no. 7: Avg QWK of all scores: 0.3268
# validation prompt no. 8: Avg QWK of all scores: 0.3147
# vg QWK across all prompts: 0.4130
#
# --------------- testing combo 18/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.4899
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0552
#
# --------------- testing combo 19/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.5163
# validation prompt no. 3: Avg QWK of all scores: 0.6133
# validation prompt no. 4: Avg QWK of all scores: 0.5577
# validation prompt no. 5: Avg QWK of all scores: 0.5770
# validation prompt no. 6: Avg QWK of all scores: 0.5316
# validation prompt no. 7: Avg QWK of all scores: 0.4083
# validation prompt no. 8: Avg QWK of all scores: 0.4530
# vg QWK across all prompts: 0.5096
# BEST COMBO FOUND =)!
#
# --------------- testing combo 20/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.3980
# validation prompt no. 3: Avg QWK of all scores: 0.4848
# validation prompt no. 4: Avg QWK of all scores: 0.5146
# validation prompt no. 5: Avg QWK of all scores: 0.5677
# validation prompt no. 6: Avg QWK of all scores: 0.4111
# validation prompt no. 7: Avg QWK of all scores: 0.3590
# validation prompt no. 8: Avg QWK of all scores: 0.3257
# vg QWK across all prompts: 0.4094
#
# --------------- testing combo 21/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 22/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.5199
# validation prompt no. 3: Avg QWK of all scores: 0.5716
# validation prompt no. 4: Avg QWK of all scores: 0.5021
# validation prompt no. 5: Avg QWK of all scores: 0.6029
# validation prompt no. 6: Avg QWK of all scores: 0.5502
# validation prompt no. 7: Avg QWK of all scores: 0.3449
# validation prompt no. 8: Avg QWK of all scores: 0.4299
# vg QWK across all prompts: 0.4901
#
# --------------- testing combo 23/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.2889
# validation prompt no. 3: Avg QWK of all scores: 0.5398
# validation prompt no. 4: Avg QWK of all scores: 0.4229
# validation prompt no. 5: Avg QWK of all scores: 0.4645
# validation prompt no. 6: Avg QWK of all scores: 0.3735
# validation prompt no. 7: Avg QWK of all scores: 0.3176
# validation prompt no. 8: Avg QWK of all scores: 0.3883
# vg QWK across all prompts: 0.3774
#
# --------------- testing combo 24/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 25/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4556
# validation prompt no. 3: Avg QWK of all scores: 0.5706
# validation prompt no. 4: Avg QWK of all scores: 0.5743
# validation prompt no. 5: Avg QWK of all scores: 0.5976
# validation prompt no. 6: Avg QWK of all scores: 0.5488
# validation prompt no. 7: Avg QWK of all scores: 0.3777
# validation prompt no. 8: Avg QWK of all scores: 0.4683
# vg QWK across all prompts: 0.4909
#
# --------------- testing combo 26/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.3691
# validation prompt no. 3: Avg QWK of all scores: 0.5510
# validation prompt no. 4: Avg QWK of all scores: 0.5287
# validation prompt no. 5: Avg QWK of all scores: 0.5350
# validation prompt no. 6: Avg QWK of all scores: 0.5586
# validation prompt no. 7: Avg QWK of all scores: 0.3370
# validation prompt no. 8: Avg QWK of all scores: 0.2842
# vg QWK across all prompts: 0.4113
#
# --------------- testing combo 27/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.3700
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0430
#
# --------------- testing combo 28/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4909
# validation prompt no. 3: Avg QWK of all scores: 0.5952
# validation prompt no. 4: Avg QWK of all scores: 0.5585
# validation prompt no. 5: Avg QWK of all scores: 0.6460
# validation prompt no. 6: Avg QWK of all scores: 0.5133
# validation prompt no. 7: Avg QWK of all scores: 0.3772
# validation prompt no. 8: Avg QWK of all scores: 0.5192
# vg QWK across all prompts: 0.5134
# BEST COMBO FOUND =)!
#
# --------------- testing combo 29/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4657
# validation prompt no. 3: Avg QWK of all scores: 0.5438
# validation prompt no. 4: Avg QWK of all scores: 0.4924
# validation prompt no. 5: Avg QWK of all scores: 0.6181
# validation prompt no. 6: Avg QWK of all scores: 0.5302
# validation prompt no. 7: Avg QWK of all scores: 0.3178
# validation prompt no. 8: Avg QWK of all scores: 0.3023
# vg QWK across all prompts: 0.4393
#
# --------------- testing combo 30/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 31/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.5094
# validation prompt no. 3: Avg QWK of all scores: 0.5824
# validation prompt no. 4: Avg QWK of all scores: 0.5726
# validation prompt no. 5: Avg QWK of all scores: 0.6336
# validation prompt no. 6: Avg QWK of all scores: 0.4675
# validation prompt no. 7: Avg QWK of all scores: 0.3580
# validation prompt no. 8: Avg QWK of all scores: 0.4282
# vg QWK across all prompts: 0.4949
#
# --------------- testing combo 32/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.5033
# validation prompt no. 3: Avg QWK of all scores: 0.5712
# validation prompt no. 4: Avg QWK of all scores: 0.5658
# validation prompt no. 5: Avg QWK of all scores: 0.5999
# validation prompt no. 6: Avg QWK of all scores: 0.5115
# validation prompt no. 7: Avg QWK of all scores: 0.3506
# validation prompt no. 8: Avg QWK of all scores: 0.2786
# vg QWK across all prompts: 0.4580
#
# --------------- testing combo 33/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 34/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.001
#
# validation prompt no. 2: Avg QWK of all scores: 0.4960
# validation prompt no. 3: Avg QWK of all scores: 0.5529
# validation prompt no. 4: Avg QWK of all scores: 0.6074
# validation prompt no. 5: Avg QWK of all scores: 0.6244
# validation prompt no. 6: Avg QWK of all scores: 0.4409
# validation prompt no. 7: Avg QWK of all scores: 0.3765
# validation prompt no. 8: Avg QWK of all scores: 0.4531
# vg QWK across all prompts: 0.4906
#
# --------------- testing combo 35/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.01
#
# validation prompt no. 2: Avg QWK of all scores: 0.4979
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.5841
# validation prompt no. 6: Avg QWK of all scores: 0.4818
# validation prompt no. 7: Avg QWK of all scores: 0.3945
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.2593
#
# --------------- testing combo 36/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.1
#
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------------------------------------------
# starting the batch size optim with best params from grid search
# --------------------------------------------------
#
# Dataset after separation:
# Training: 10470 essays (prompts [2, 3, 4, 5, 6, 7])
# Validation: 723 essays (prompt 8)
# Held out: Prompt 1 (for final testing)
#
# testing batch sizes: [4, 8, 16, 32]
# 	esting batch size: 4
# Epoch 5/15 - Train Loss: 0.032592, Val Loss: 0.039513
# early stopping at epoch 6
# avg validation QWK across all traits: 0.4401
# trait QWKs:
# holistic: 0.5755
# content: 0.4332
# organization: 0.3261
# word_choice: 0.5591
# sentence_fluency: 0.5382
# conventions: 0.2085
# New best batch size found!!!!! :)
# 	esting batch size: 8
# Epoch 5/15 - Train Loss: 0.032398, Val Loss: 0.026008
# early stopping at epoch 8
# avg validation QWK across all traits: 0.4051
# trait QWKs:
# holistic: 0.4882
# content: 0.3294
# organization: 0.2667
# word_choice: 0.6065
# sentence_fluency: 0.5291
# conventions: 0.2105
# 	esting batch size: 16
# Epoch 5/15 - Train Loss: 0.032097, Val Loss: 0.039323
# early stopping at epoch 6
# avg validation QWK across all traits: 0.4244
# trait QWKs:
# holistic: 0.5716
# content: 0.3866
# organization: 0.2943
# word_choice: 0.6371
# sentence_fluency: 0.4575
# conventions: 0.1991
# 	esting batch size: 32
# early stopping at epoch 4
# avg validation QWK across all traits: 0.3915
# trait QWKs:
# holistic: 0.3765
# content: 0.3430
# organization: 0.3316
# word_choice: 0.6100
# sentence_fluency: 0.4610
# conventions: 0.2270
#
# --------------------------------------------------
# done with batch size optimization :D
# total time taken: 11.99 seconds (0.20 minutes)
# best batch size: 4
# best validation average QWK: 0.4401
# --------------------------------------------------
#
# starting training the final model
# Epoch 5/15 - Training Loss: 0.031405
# Epoch 10/15 - Training Loss: 0.030954
# Epoch 15/15 - Training Loss: 0.030914
#
# --------------------------------------------------
# Test set results on target prompt 1:
# Holistic QWK: 0.7452
# Content QWK: 0.6379
# Organization QWK: 0.5584
# Word_choice QWK: 0.5661
# Sentence_fluency QWK: 0.5331
# Conventions QWK: 0.5369
# final best params: {'hidden_unit': 32, 'num_layers': 2, 'learning_rate': 0.001, 'batch_size': 4}
# --------------------------------------------------
#
# model was saved as model-B-1.pt
#
# ------------------------------------------------------------
# model starts training process for target prompt 2
# ------------------------------------------------------------
#
# Feature shape: torch.Size([11178, 86])
# Scores shape: torch.Size([11178, 9])
# Model does grid search with 36 combinations
# - hidden units per layer (D): [8, 16, 32]
# - num of layers (k): [1, 2, 4, 8]
# - learning rates: [0.001, 0.01, 0.1]
# - batch size (fixed): 4
#
#
# --------------- testing combo 1/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5377
# validation prompt no. 3: Avg QWK of all scores: 0.5679
# validation prompt no. 4: Avg QWK of all scores: 0.5135
# validation prompt no. 5: Avg QWK of all scores: 0.6169
# validation prompt no. 6: Avg QWK of all scores: 0.5358
# validation prompt no. 7: Avg QWK of all scores: 0.3935
# validation prompt no. 8: Avg QWK of all scores: 0.3887
# vg QWK across all prompts: 0.4819
# BEST COMBO FOUND =)!
#
# --------------- testing combo 2/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4848
# validation prompt no. 3: Avg QWK of all scores: 0.5055
# validation prompt no. 4: Avg QWK of all scores: 0.5212
# validation prompt no. 5: Avg QWK of all scores: 0.5646
# validation prompt no. 6: Avg QWK of all scores: 0.5155
# validation prompt no. 7: Avg QWK of all scores: 0.2919
# validation prompt no. 8: Avg QWK of all scores: 0.4495
# vg QWK across all prompts: 0.4519
#
# --------------- testing combo 3/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 4/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5187
# validation prompt no. 3: Avg QWK of all scores: 0.5501
# validation prompt no. 4: Avg QWK of all scores: 0.5555
# validation prompt no. 5: Avg QWK of all scores: 0.5977
# validation prompt no. 6: Avg QWK of all scores: 0.5342
# validation prompt no. 7: Avg QWK of all scores: 0.3871
# validation prompt no. 8: Avg QWK of all scores: 0.3838
# vg QWK across all prompts: 0.4758
#
# --------------- testing combo 5/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4597
# validation prompt no. 3: Avg QWK of all scores: 0.5363
# validation prompt no. 4: Avg QWK of all scores: 0.4487
# validation prompt no. 5: Avg QWK of all scores: 0.4290
# validation prompt no. 6: Avg QWK of all scores: 0.4043
# validation prompt no. 7: Avg QWK of all scores: 0.3570
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.3239
#
# --------------- testing combo 6/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 7/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5736
# validation prompt no. 3: Avg QWK of all scores: 0.5589
# validation prompt no. 4: Avg QWK of all scores: 0.5900
# validation prompt no. 5: Avg QWK of all scores: 0.5602
# validation prompt no. 6: Avg QWK of all scores: 0.5328
# validation prompt no. 7: Avg QWK of all scores: 0.3893
# validation prompt no. 8: Avg QWK of all scores: 0.4303
# vg QWK across all prompts: 0.5029
# BEST COMBO FOUND =)!
#
# --------------- testing combo 8/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4744
# validation prompt no. 3: Avg QWK of all scores: 0.3962
# validation prompt no. 4: Avg QWK of all scores: 0.4604
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3096
# validation prompt no. 8: Avg QWK of all scores: 0.3661
# vg QWK across all prompts: 0.2939
#
# --------------- testing combo 9/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 10/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5488
# validation prompt no. 3: Avg QWK of all scores: 0.5411
# validation prompt no. 4: Avg QWK of all scores: 0.5720
# validation prompt no. 5: Avg QWK of all scores: 0.6116
# validation prompt no. 6: Avg QWK of all scores: 0.4101
# validation prompt no. 7: Avg QWK of all scores: 0.3953
# validation prompt no. 8: Avg QWK of all scores: 0.3722
# vg QWK across all prompts: 0.4718
#
# --------------- testing combo 11/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4588
# validation prompt no. 3: Avg QWK of all scores: 0.5443
# validation prompt no. 4: Avg QWK of all scores: 0.4694
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3317
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.2291
#
# --------------- testing combo 12/36--------------
# hyperparams: units per layer D=8, num of layers k=8, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 13/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5281
# validation prompt no. 3: Avg QWK of all scores: 0.5591
# validation prompt no. 4: Avg QWK of all scores: 0.5555
# validation prompt no. 5: Avg QWK of all scores: 0.6269
# validation prompt no. 6: Avg QWK of all scores: 0.5397
# validation prompt no. 7: Avg QWK of all scores: 0.3877
# validation prompt no. 8: Avg QWK of all scores: 0.4583
# vg QWK across all prompts: 0.5035
# BEST COMBO FOUND =)!
#
# --------------- testing combo 14/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5254
# validation prompt no. 3: Avg QWK of all scores: 0.5542
# validation prompt no. 4: Avg QWK of all scores: 0.4582
# validation prompt no. 5: Avg QWK of all scores: 0.6230
# validation prompt no. 6: Avg QWK of all scores: 0.5290
# validation prompt no. 7: Avg QWK of all scores: 0.3807
# validation prompt no. 8: Avg QWK of all scores: 0.4348
# vg QWK across all prompts: 0.4849
#
# --------------- testing combo 15/36--------------
# hyperparams: units per layer D=16, num of layers k=1, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0937
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0112
#
# --------------- testing combo 16/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5142
# validation prompt no. 3: Avg QWK of all scores: 0.5878
# validation prompt no. 4: Avg QWK of all scores: 0.5504
# validation prompt no. 5: Avg QWK of all scores: 0.6331
# validation prompt no. 6: Avg QWK of all scores: 0.5176
# validation prompt no. 7: Avg QWK of all scores: 0.3599
# validation prompt no. 8: Avg QWK of all scores: 0.4508
# vg QWK across all prompts: 0.4977
#
# --------------- testing combo 17/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4907
# validation prompt no. 3: Avg QWK of all scores: 0.5314
# validation prompt no. 4: Avg QWK of all scores: 0.5464
# validation prompt no. 5: Avg QWK of all scores: 0.5487
# validation prompt no. 6: Avg QWK of all scores: 0.4325
# validation prompt no. 7: Avg QWK of all scores: 0.3743
# validation prompt no. 8: Avg QWK of all scores: 0.4455
# vg QWK across all prompts: 0.4669
#
# --------------- testing combo 18/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 19/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5723
# validation prompt no. 3: Avg QWK of all scores: 0.5801
# validation prompt no. 4: Avg QWK of all scores: 0.5930
# validation prompt no. 5: Avg QWK of all scores: 0.6529
# validation prompt no. 6: Avg QWK of all scores: 0.5536
# validation prompt no. 7: Avg QWK of all scores: 0.4024
# validation prompt no. 8: Avg QWK of all scores: 0.4677
# vg QWK across all prompts: 0.5305
# BEST COMBO FOUND =)!
#
# --------------- testing combo 20/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.3871
# validation prompt no. 3: Avg QWK of all scores: 0.4088
# validation prompt no. 4: Avg QWK of all scores: 0.4223
# validation prompt no. 5: Avg QWK of all scores: 0.6443
# validation prompt no. 6: Avg QWK of all scores: 0.3151
# validation prompt no. 7: Avg QWK of all scores: 0.4139
# validation prompt no. 8: Avg QWK of all scores: 0.3597
# vg QWK across all prompts: 0.3988
#
# --------------- testing combo 21/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 22/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5393
# validation prompt no. 3: Avg QWK of all scores: 0.6100
# validation prompt no. 4: Avg QWK of all scores: 0.5215
# validation prompt no. 5: Avg QWK of all scores: 0.6377
# validation prompt no. 6: Avg QWK of all scores: 0.4741
# validation prompt no. 7: Avg QWK of all scores: 0.4418
# validation prompt no. 8: Avg QWK of all scores: 0.4920
# vg QWK across all prompts: 0.5155
#
# --------------- testing combo 23/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.3255
# validation prompt no. 3: Avg QWK of all scores: 0.4406
# validation prompt no. 4: Avg QWK of all scores: 0.5434
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.4934
# validation prompt no. 7: Avg QWK of all scores: 0.3375
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.2523
#
# --------------- testing combo 24/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 25/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5476
# validation prompt no. 3: Avg QWK of all scores: 0.5971
# validation prompt no. 4: Avg QWK of all scores: 0.5666
# validation prompt no. 5: Avg QWK of all scores: 0.5901
# validation prompt no. 6: Avg QWK of all scores: 0.5458
# validation prompt no. 7: Avg QWK of all scores: 0.3921
# validation prompt no. 8: Avg QWK of all scores: 0.4585
# vg QWK across all prompts: 0.5133
#
# --------------- testing combo 26/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4376
# validation prompt no. 3: Avg QWK of all scores: 0.5570
# validation prompt no. 4: Avg QWK of all scores: 0.5927
# validation prompt no. 5: Avg QWK of all scores: 0.5438
# validation prompt no. 6: Avg QWK of all scores: 0.4568
# validation prompt no. 7: Avg QWK of all scores: 0.3711
# validation prompt no. 8: Avg QWK of all scores: 0.3238
# vg QWK across all prompts: 0.4443
#
# --------------- testing combo 27/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.2765
# vg QWK across all prompts: 0.0657
#
# --------------- testing combo 28/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5416
# validation prompt no. 3: Avg QWK of all scores: 0.5816
# validation prompt no. 4: Avg QWK of all scores: 0.5918
# validation prompt no. 5: Avg QWK of all scores: 0.5717
# validation prompt no. 6: Avg QWK of all scores: 0.5560
# validation prompt no. 7: Avg QWK of all scores: 0.3905
# validation prompt no. 8: Avg QWK of all scores: 0.4961
# vg QWK across all prompts: 0.5226
#
# --------------- testing combo 29/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5625
# validation prompt no. 3: Avg QWK of all scores: 0.5399
# validation prompt no. 4: Avg QWK of all scores: 0.6428
# validation prompt no. 5: Avg QWK of all scores: 0.5976
# validation prompt no. 6: Avg QWK of all scores: 0.4376
# validation prompt no. 7: Avg QWK of all scores: 0.3355
# validation prompt no. 8: Avg QWK of all scores: 0.4106
# vg QWK across all prompts: 0.4884
#
# --------------- testing combo 30/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3056
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0274
#
# --------------- testing combo 31/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5061
# validation prompt no. 3: Avg QWK of all scores: 0.6018
# validation prompt no. 4: Avg QWK of all scores: 0.5939
# validation prompt no. 5: Avg QWK of all scores: 0.5995
# validation prompt no. 6: Avg QWK of all scores: 0.5678
# validation prompt no. 7: Avg QWK of all scores: 0.3732
# validation prompt no. 8: Avg QWK of all scores: 0.5019
# vg QWK across all prompts: 0.5238
#
# --------------- testing combo 32/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4446
# validation prompt no. 3: Avg QWK of all scores: 0.4780
# validation prompt no. 4: Avg QWK of all scores: 0.5623
# validation prompt no. 5: Avg QWK of all scores: 0.5930
# validation prompt no. 6: Avg QWK of all scores: 0.4077
# validation prompt no. 7: Avg QWK of all scores: 0.3516
# validation prompt no. 8: Avg QWK of all scores: 0.3924
# vg QWK across all prompts: 0.4334
#
# --------------- testing combo 33/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 34/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.4664
# validation prompt no. 3: Avg QWK of all scores: 0.6121
# validation prompt no. 4: Avg QWK of all scores: 0.5703
# validation prompt no. 5: Avg QWK of all scores: 0.5266
# validation prompt no. 6: Avg QWK of all scores: 0.5679
# validation prompt no. 7: Avg QWK of all scores: 0.3795
# validation prompt no. 8: Avg QWK of all scores: 0.4605
# vg QWK across all prompts: 0.4828
#
# --------------- testing combo 35/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4415
# validation prompt no. 3: Avg QWK of all scores: 0.5879
# validation prompt no. 4: Avg QWK of all scores: 0.4761
# validation prompt no. 5: Avg QWK of all scores: 0.5357
# validation prompt no. 6: Avg QWK of all scores: 0.4205
# validation prompt no. 7: Avg QWK of all scores: 0.3983
# validation prompt no. 8: Avg QWK of all scores: 0.4525
# vg QWK across all prompts: 0.4401
#
# --------------- testing combo 36/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------------------------------------------
# starting the batch size optim with best params from grid search
# --------------------------------------------------
#
# Dataset after separation:
# Training: 10455 essays (prompts [1, 3, 4, 5, 6, 7])
# Validation: 723 essays (prompt 8)
# Held out: Prompt 2 (for final testing)
#
# testing batch sizes: [4, 8, 16, 32]
# 	esting batch size: 4
# Epoch 5/15 - Train Loss: 0.032458, Val Loss: 0.024312
# Epoch 10/15 - Train Loss: 0.032225, Val Loss: 0.027215
# early stopping at epoch 11
# avg validation QWK across all traits: 0.4472
# trait QWKs:
# holistic: 0.4076
# content: 0.4970
# organization: 0.4540
# word_choice: 0.5461
# sentence_fluency: 0.5077
# conventions: 0.2708
# New best batch size found!!!!! :)
# 	esting batch size: 8
# Epoch 5/15 - Train Loss: 0.031677, Val Loss: 0.022079
# early stopping at epoch 8
# avg validation QWK across all traits: 0.4791
# trait QWKs:
# holistic: 0.4961
# content: 0.4210
# organization: 0.4602
# word_choice: 0.5955
# sentence_fluency: 0.5589
# conventions: 0.3426
# New best batch size found!!!!! :)
# 	esting batch size: 16
# early stopping at epoch 4
# avg validation QWK across all traits: 0.4562
# trait QWKs:
# holistic: 0.4133
# content: 0.5213
# organization: 0.4811
# word_choice: 0.5291
# sentence_fluency: 0.4817
# conventions: 0.3110
# 	esting batch size: 32
# early stopping at epoch 5
# avg validation QWK across all traits: 0.4553
# trait QWKs:
# holistic: 0.4727
# content: 0.4481
# organization: 0.4722
# word_choice: 0.5997
# sentence_fluency: 0.4471
# conventions: 0.2922
#
# --------------------------------------------------
# done with batch size optimization :D
# total time taken: 21.57 seconds (0.36 minutes)
# best batch size: 8
# best validation average QWK: 0.4791
# --------------------------------------------------
#
# starting training the final model
# Epoch 5/15 - Training Loss: 0.030377
# Epoch 10/15 - Training Loss: 0.029815
# Epoch 15/15 - Training Loss: 0.029569
#
# --------------------------------------------------
# Test set results on target prompt 2:
# Holistic QWK: 0.5437
# Content QWK: 0.6065
# Organization QWK: 0.4972
# Word_choice QWK: 0.5438
# Sentence_fluency QWK: 0.5477
# Conventions QWK: 0.3936
# final best params: {'hidden_unit': 16, 'num_layers': 4, 'learning_rate': 0.001, 'batch_size': 8}
# --------------------------------------------------
#
# model was saved as model-B-2.pt
#
# ------------------------------------------------------------
# model starts training process for target prompt 3
# ------------------------------------------------------------
#
# Feature shape: torch.Size([11250, 86])
# Scores shape: torch.Size([11250, 9])
# Model does grid search with 36 combinations
# - hidden units per layer (D): [8, 16, 32]
# - num of layers (k): [1, 2, 4, 8]
# - learning rates: [0.001, 0.01, 0.1]
# - batch size (fixed): 4
#
#
# --------------- testing combo 1/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5474
# validation prompt no. 2: Avg QWK of all scores: 0.5685
# validation prompt no. 4: Avg QWK of all scores: 0.4752
# validation prompt no. 5: Avg QWK of all scores: 0.5883
# validation prompt no. 6: Avg QWK of all scores: 0.5063
# validation prompt no. 7: Avg QWK of all scores: 0.3151
# validation prompt no. 8: Avg QWK of all scores: 0.4621
# vg QWK across all prompts: 0.4976
# BEST COMBO FOUND =)!
#
# --------------- testing combo 2/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5838
# validation prompt no. 2: Avg QWK of all scores: 0.3840
# validation prompt no. 4: Avg QWK of all scores: 0.4588
# validation prompt no. 5: Avg QWK of all scores: 0.5340
# validation prompt no. 6: Avg QWK of all scores: 0.4768
# validation prompt no. 7: Avg QWK of all scores: 0.3684
# validation prompt no. 8: Avg QWK of all scores: 0.4178
# vg QWK across all prompts: 0.4522
#
# --------------- testing combo 3/36--------------
# hyperparams: units per layer D=8, num of layers k=1, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 4/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5651
# validation prompt no. 2: Avg QWK of all scores: 0.5633
# validation prompt no. 4: Avg QWK of all scores: 0.4923
# validation prompt no. 5: Avg QWK of all scores: 0.6150
# validation prompt no. 6: Avg QWK of all scores: 0.5112
# validation prompt no. 7: Avg QWK of all scores: 0.3445
# validation prompt no. 8: Avg QWK of all scores: 0.4266
# vg QWK across all prompts: 0.5021
# BEST COMBO FOUND =)!
#
# --------------- testing combo 5/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.6136
# validation prompt no. 2: Avg QWK of all scores: 0.4534
# validation prompt no. 4: Avg QWK of all scores: 0.4854
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.5000
# validation prompt no. 7: Avg QWK of all scores: 0.3795
# validation prompt no. 8: Avg QWK of all scores: 0.3600
# vg QWK across all prompts: 0.3937
#
# --------------- testing combo 6/36--------------
# hyperparams: units per layer D=8, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# validation prompt no. 8: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 7/36--------------
# hyperparams: units per layer D=8, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5940
# ...
# validation prompt no. 3: Avg QWK of all scores: 0.5969
# validation prompt no. 4: Avg QWK of all scores: 0.4812
# validation prompt no. 5: Avg QWK of all scores: 0.6474
# validation prompt no. 6: Avg QWK of all scores: 0.5099
# validation prompt no. 7: Avg QWK of all scores: 0.3806
# vg QWK across all prompts: 0.5267
#
# --------------- testing combo 17/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5161
# validation prompt no. 2: Avg QWK of all scores: 0.4824
# validation prompt no. 3: Avg QWK of all scores: 0.5308
# validation prompt no. 4: Avg QWK of all scores: 0.4951
# validation prompt no. 5: Avg QWK of all scores: 0.6370
# validation prompt no. 6: Avg QWK of all scores: 0.4873
# validation prompt no. 7: Avg QWK of all scores: 0.3011
# vg QWK across all prompts: 0.4820
#
# --------------- testing combo 18/36--------------
# hyperparams: units per layer D=16, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 19/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.5733
# validation prompt no. 2: Avg QWK of all scores: 0.5418
# validation prompt no. 3: Avg QWK of all scores: 0.5906
# validation prompt no. 4: Avg QWK of all scores: 0.5603
# validation prompt no. 5: Avg QWK of all scores: 0.6101
# validation prompt no. 6: Avg QWK of all scores: 0.5258
# validation prompt no. 7: Avg QWK of all scores: 0.3996
# vg QWK across all prompts: 0.5322
#
# --------------- testing combo 20/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5216
# validation prompt no. 2: Avg QWK of all scores: 0.4546
# validation prompt no. 3: Avg QWK of all scores: 0.5073
# validation prompt no. 4: Avg QWK of all scores: 0.4749
# validation prompt no. 5: Avg QWK of all scores: 0.6260
# validation prompt no. 6: Avg QWK of all scores: 0.4188
# validation prompt no. 7: Avg QWK of all scores: 0.3750
# vg QWK across all prompts: 0.4585
#
# --------------- testing combo 21/36--------------
# hyperparams: units per layer D=16, num of layers k=4, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 22/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.6294
# validation prompt no. 2: Avg QWK of all scores: 0.5170
# validation prompt no. 3: Avg QWK of all scores: 0.6148
# validation prompt no. 4: Avg QWK of all scores: 0.5860
# validation prompt no. 5: Avg QWK of all scores: 0.5373
# validation prompt no. 6: Avg QWK of all scores: 0.4477
# validation prompt no. 7: Avg QWK of all scores: 0.4122
# vg QWK across all prompts: 0.5289
#
# --------------- testing combo 23/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.4235
# validation prompt no. 3: Avg QWK of all scores: 0.4873
# validation prompt no. 4: Avg QWK of all scores: 0.4468
# validation prompt no. 5: Avg QWK of all scores: 0.5846
# validation prompt no. 6: Avg QWK of all scores: 0.4463
# validation prompt no. 7: Avg QWK of all scores: 0.3256
# vg QWK across all prompts: 0.3442
#
# --------------- testing combo 24/36--------------
# hyperparams: units per layer D=16, num of layers k=8, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 25/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.6029
# validation prompt no. 2: Avg QWK of all scores: 0.5785
# validation prompt no. 3: Avg QWK of all scores: 0.5891
# validation prompt no. 4: Avg QWK of all scores: 0.5737
# validation prompt no. 5: Avg QWK of all scores: 0.5766
# validation prompt no. 6: Avg QWK of all scores: 0.5465
# validation prompt no. 7: Avg QWK of all scores: 0.3755
# vg QWK across all prompts: 0.5427
#
# --------------- testing combo 26/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4668
# validation prompt no. 2: Avg QWK of all scores: 0.3720
# validation prompt no. 3: Avg QWK of all scores: 0.5455
# validation prompt no. 4: Avg QWK of all scores: 0.5094
# validation prompt no. 5: Avg QWK of all scores: 0.4933
# validation prompt no. 6: Avg QWK of all scores: 0.5040
# validation prompt no. 7: Avg QWK of all scores: 0.3872
# vg QWK across all prompts: 0.4345
#
# --------------- testing combo 27/36--------------
# hyperparams: units per layer D=32, num of layers k=1, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.3081
# vg QWK across all prompts: 0.0264
#
# --------------- testing combo 28/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.6358
# validation prompt no. 2: Avg QWK of all scores: 0.5841
# validation prompt no. 3: Avg QWK of all scores: 0.6021
# validation prompt no. 4: Avg QWK of all scores: 0.5698
# validation prompt no. 5: Avg QWK of all scores: 0.6090
# validation prompt no. 6: Avg QWK of all scores: 0.5356
# validation prompt no. 7: Avg QWK of all scores: 0.3630
# vg QWK across all prompts: 0.5526
# BEST COMBO FOUND =)!
#
# --------------- testing combo 29/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5662
# validation prompt no. 2: Avg QWK of all scores: 0.5042
# validation prompt no. 3: Avg QWK of all scores: 0.5625
# validation prompt no. 4: Avg QWK of all scores: 0.5240
# validation prompt no. 5: Avg QWK of all scores: 0.5874
# validation prompt no. 6: Avg QWK of all scores: 0.5406
# validation prompt no. 7: Avg QWK of all scores: 0.3683
# vg QWK across all prompts: 0.5075
#
# --------------- testing combo 30/36--------------
# hyperparams: units per layer D=32, num of layers k=2, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 31/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.6071
# validation prompt no. 2: Avg QWK of all scores: 0.5626
# validation prompt no. 3: Avg QWK of all scores: 0.5789
# validation prompt no. 4: Avg QWK of all scores: 0.5896
# validation prompt no. 5: Avg QWK of all scores: 0.6034
# validation prompt no. 6: Avg QWK of all scores: 0.5103
# validation prompt no. 7: Avg QWK of all scores: 0.3993
# vg QWK across all prompts: 0.5428
#
# --------------- testing combo 32/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.5869
# validation prompt no. 2: Avg QWK of all scores: 0.4253
# validation prompt no. 3: Avg QWK of all scores: 0.5761
# validation prompt no. 4: Avg QWK of all scores: 0.5438
# validation prompt no. 5: Avg QWK of all scores: 0.5172
# validation prompt no. 6: Avg QWK of all scores: 0.4658
# validation prompt no. 7: Avg QWK of all scores: 0.4292
# vg QWK across all prompts: 0.4858
#
# --------------- testing combo 33/36--------------
# hyperparams: units per layer D=32, num of layers k=4, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------- testing combo 34/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.001
#
# validation prompt no. 1: Avg QWK of all scores: 0.4992
# validation prompt no. 2: Avg QWK of all scores: 0.5582
# validation prompt no. 3: Avg QWK of all scores: 0.5865
# validation prompt no. 4: Avg QWK of all scores: 0.5338
# validation prompt no. 5: Avg QWK of all scores: 0.6386
# validation prompt no. 6: Avg QWK of all scores: 0.4667
# validation prompt no. 7: Avg QWK of all scores: 0.3922
# vg QWK across all prompts: 0.5133
#
# --------------- testing combo 35/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.01
#
# validation prompt no. 1: Avg QWK of all scores: 0.4207
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.3768
# validation prompt no. 4: Avg QWK of all scores: 0.5768
# validation prompt no. 5: Avg QWK of all scores: 0.5641
# validation prompt no. 6: Avg QWK of all scores: 0.5439
# validation prompt no. 7: Avg QWK of all scores: 0.2537
# vg QWK across all prompts: 0.3390
#
# --------------- testing combo 36/36--------------
# hyperparams: units per layer D=32, num of layers k=8, lr=0.1
#
# validation prompt no. 1: Avg QWK of all scores: 0.0000
# validation prompt no. 2: Avg QWK of all scores: 0.0000
# validation prompt no. 3: Avg QWK of all scores: 0.0000
# validation prompt no. 4: Avg QWK of all scores: 0.0000
# validation prompt no. 5: Avg QWK of all scores: 0.0000
# validation prompt no. 6: Avg QWK of all scores: 0.0000
# validation prompt no. 7: Avg QWK of all scores: 0.0000
# vg QWK across all prompts: 0.0000
#
# --------------------------------------------------
# starting the batch size optim with best params from grid search
# --------------------------------------------------
#
# Dataset after separation:
# Training: 10684 essays (prompts [1, 2, 3, 4, 5, 6])
# Validation: 1569 essays (prompt 7)
# Held out: Prompt 8 (for final testing)
#
# testing batch sizes: [4, 8, 16, 32]
# 	esting batch size: 4
# Epoch 5/15 - Train Loss: 0.031348, Val Loss: 0.080341
# early stopping at epoch 6
# avg validation QWK across all traits: 0.4083
# trait QWKs:
# holistic: 0.7196
# content: 0.3502
# organization: 0.3098
# conventions: 0.2536
# New best batch size found!!!!! :)
# 	esting batch size: 8
# early stopping at epoch 4
# avg validation QWK across all traits: 0.4080
# trait QWKs:
# holistic: 0.7340
# content: 0.3498
# organization: 0.3058
# conventions: 0.2424
# 	esting batch size: 16
# Epoch 5/15 - Train Loss: 0.030763, Val Loss: 0.091396
# early stopping at epoch 7
# avg validation QWK across all traits: 0.3750
# trait QWKs:
# holistic: 0.7258
# content: 0.3264
# organization: 0.2372
# conventions: 0.2106
# 	esting batch size: 32
# early stopping at epoch 4
# avg validation QWK across all traits: 0.3471
# trait QWKs:
# holistic: 0.7059
# content: 0.2889
# organization: 0.2193
# conventions: 0.1741
#
# --------------------------------------------------
# done with batch size optimization :D
# total time taken: 10.78 seconds (0.18 minutes)
# best batch size: 4
# best validation average QWK: 0.4083
# --------------------------------------------------
#
# starting training the final model
# Epoch 5/15 - Training Loss: 0.030237
# Epoch 10/15 - Training Loss: 0.030212
# Epoch 15/15 - Training Loss: 0.030175
#
# --------------------------------------------------
# Test set results on target prompt 8:
# Holistic QWK: 0.5029
# Content QWK: 0.5552
# Organization QWK: 0.5715
# Word_choice QWK: 0.5245
# Sentence_fluency QWK: 0.5810
# Conventions QWK: 0.4650
# final best params: {'hidden_unit': 32, 'num_layers': 2, 'learning_rate': 0.001, 'batch_size': 4}
# --------------------------------------------------
#
# model was saved as model-B-8.pt
#
# Final Results Summary:
# --------------------------------------------------
#
# Prompt 1:
#   Holistic QWK: 0.7452
#   Content QWK: 0.6379
#   Organization QWK: 0.5584
#   Word_choice QWK: 0.5661
#   Sentence_fluency QWK: 0.5331
#   Conventions QWK: 0.5369
#   Parameters: {'hidden_unit': 32, 'num_layers': 2, 'learning_rate': 0.001, 'batch_size': 4}
#
# Prompt 2:
#   Holistic QWK: 0.5437
#   Content QWK: 0.6065
#   Organization QWK: 0.4972
#   Word_choice QWK: 0.5438
#   Sentence_fluency QWK: 0.5477
#   Conventions QWK: 0.3936
#   Parameters: {'hidden_unit': 16, 'num_layers': 4, 'learning_rate': 0.001, 'batch_size': 8}
#
# Prompt 3:
#   Holistic QWK: 0.6480
#   Content QWK: 0.6233
#   Prompt_adherence QWK: 0.5954
#   Language QWK: 0.5769
#   Narrativity QWK: 0.6315
#   Parameters: {'hidden_unit': 32, 'num_layers': 4, 'learning_rate': 0.001, 'batch_size': 32}
#
# Prompt 4:
#   Holistic QWK: 0.6413
#   Content QWK: 0.5904
#   Prompt_adherence QWK: 0.6084
#   Language QWK: 0.5135
#   Narrativity QWK: 0.6081
#   Parameters: {'hidden_unit': 32, 'num_layers': 2, 'learning_rate': 0.001, 'batch_size': 32}
#
# Prompt 5:
#   Holistic QWK: 0.6996
#   Content QWK: 0.6520
#   Prompt_adherence QWK: 0.5573
#   Language QWK: 0.4744
#   Narrativity QWK: 0.6043
#   Parameters: {'hidden_unit': 32, 'num_layers': 1, 'learning_rate': 0.001, 'batch_size': 16}
#
# Prompt 6:
#   Holistic QWK: 0.4354
#   Content QWK: 0.4669
#   Prompt_adherence QWK: 0.5013
#   Language QWK: 0.4489
#   Narrativity QWK: 0.4991
#   Parameters: {'hidden_unit': 32, 'num_layers': 8, 'learning_rate': 0.001, 'batch_size': 4}
#
# Prompt 7:
#   Holistic QWK: 0.6910
#   Content QWK: 0.3307
#   Organization QWK: 0.2752
#   Conventions QWK: 0.2215
#   Parameters: {'hidden_unit': 32, 'num_layers': 4, 'learning_rate': 0.01, 'batch_size': 32}
#
# Prompt 8:
#   Holistic QWK: 0.5029
#   Content QWK: 0.5552
#   Organization QWK: 0.5715
#   Word_choice QWK: 0.5245
#   Sentence_fluency QWK: 0.5810
#   Conventions QWK: 0.4650
#   Parameters: {'hidden_unit': 32, 'num_layers': 2, 'learning_rate': 0.001, 'batch_size': 4}
# --------------------------------------------------
#
# Average QWK per trait:
# Holistic: 0.6134
# Content: 0.5579
# Organization: 0.4755
# Word_choice: 0.5448
# Sentence_fluency: 0.5539
# Conventions: 0.4042
# Prompt_adherence: 0.5656
# Language: 0.5034
# Narrativity: 0.5858
#
# --------------------------------------------------
# Training deployment model using best parameters:
# Parameters: {'hidden_unit': 32, 'num_layers': 4, 'learning_rate': 0.001, 'batch_size': 32}
# --------------------------------------------------
# starting training of the deployment model
# Epoch 5/15 - Training Loss: 0.028645
# Epoch 10/15 - Training Loss: 0.027443
# Epoch 15/15 - Training Loss: 0.026836
#
# Saving deployment model...
# Deployment model saved as model-B-deploy.pt
#
# Final saved models:
# --------------------------------------------------
# Individual prompt models:
#   - model-B-1.pt
#   - model-B-2.pt
#   - model-B-3.pt
#   - model-B-4.pt
#   - model-B-5.pt
#   - model-B-6.pt
#   - model-B-7.pt
#   - model-B-8.pt
# Deployment model:
#   - model-B-deploy.pt
